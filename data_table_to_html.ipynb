# %%
import os
import csv
import pandas as pd

# %%
output = "Resources/hw_cities_output.csv"

# %%
df = pd.read_csv(output)
df.head()
# Out:
#          City     lats      lngs  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      castro -24.7911  -50.0119     61.52        68          47        8.68
# 1  santa rosa  14.3122  121.1114     80.58        86         100        4.45
# 2      barrow  71.2906 -156.7887     44.62        76           1        6.91
# 3    ulaangom  49.9811   92.0667     54.68        50          27        6.46
# 4       enshi  30.3000  109.4833     69.12        86          35        0.76
#
#   Country        Date
# 0      BR  1624470078
# 1      PH  1624469545
# 2      US  1624470001
# 3      MN  1624470078
# 4      CN  1624470079

# %%
html_table = df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>lats</th>\n      <th>lngs</th>\n      <th>Max Temp</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n      <th>Wind Speed</th>\n      <th>Country</th>\n      <th>Date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>castro</td>\n      <td>-24.7911</td>\n      <td>-50.0119</td>\n      <td>61.52</td>\n      <td>68</td>\n      <td>47</td>\n      <td>8.68</td>\n      <td>BR</td>\n      <td>1624470078</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>santa rosa</td>\n      <td>14.3122</td>\n      <td>121.1114</td>\n      <td>80.58</td>\n      <td>86</td>\n      <td>100</td>\n      <td>4.45</td>\n      <td>PH</td>\n      <td>1624469545</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>barrow</td>\n      <td>71.2906</td>\n      <td>-156.7887</td>\n      <td>44.62</td>\n      <td>76</td>\n      <td>1</td>\n      
# ...

# %%
html_table.replace('\n','')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>City</th>      <th>lats</th>      <th>lngs</th>      <th>Max Temp</th>      <th>Humidity</th>      <th>Cloudiness</th>      <th>Wind Speed</th>      <th>Country</th>      <th>Date</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>castro</td>      <td>-24.7911</td>      <td>-50.0119</td>      <td>61.52</td>      <td>68</td>      <td>47</td>      <td>8.68</td>      <td>BR</td>      <td>1624470078</td>    </tr>    <tr>      <th>1</th>      <td>santa rosa</td>      <td>14.3122</td>      <td>121.1114</td>      <td>80.58</td>      <td>86</td>      <td>100</td>      <td>4.45</td>      <td>PH</td>      <td>1624469545</td>    </tr>    <tr>      <th>2</th>      <td>barrow</td>      <td>71.2906</td>      <td>-156.7887</td>      <td>44.62</td>      <td>76</td>      <td>1</td>      <td>6.91</td>      <td>US</td>      <td>1624470001</td>    </tr>    <tr>      <th>3</th>      <t
# ...

# %%
df.to_html('table.html')
